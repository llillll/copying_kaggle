# %%
# commit test

print("hello world")
# Out:
# hello world

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/copy_kaggle/copy_kaggle
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/copy_kaggle/copy_kaggle'
# /content
